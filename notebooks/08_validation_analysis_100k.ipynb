# %% [markdown]
# # Validation Metrics
#
# This section evaluates the model using traditional classification metrics.
#
# We report:
# - Validation loss
# - Top-1 accuracy
# - Top-3 accuracy
# - Top-5 accuracy
#
# These metrics provide a baseline comparison with previous supervised learning approaches.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent

sys.path.append(str(project_root))

# %%
import torch

from torch.utils.data import DataLoader

from tqdm import tqdm

import sqlite3

import json

import gzip

import pandas as pd

# %%
from src.data.tokenizer import MahjongTokenizer

from src.features.tensorization import Tensorizer

from src.data.dataset import MahjongDataset

from src.data.collator import MahjongCollator

from src.models.transformer_model import (
    MahjongTransformer
)

from src.training.metrics import (
    compute_topk_accuracy,
)

from src.utils.tile_decoder import (
    tile136_to_string,
)

from src.utils.action_decoder import (
    decode_action,
)

from src.analysis.ukeire import (
    evaluate_discards_ukeire,
)

from src.analysis.error_analysis import (
    categorize_mistake,
)

# %%
tokenizer = MahjongTokenizer()

tensorizer = Tensorizer()

collator = MahjongCollator()

# %%
val_dataset = MahjongDataset(

    db_path="../data/discard/strategic.db",

    limit=100000,
)

print(len(val_dataset))
# Out:
# 100000

# %%
val_loader = DataLoader(

    val_dataset,

    batch_size=64,

    shuffle=False,

    collate_fn=collator.collate,

    num_workers=4,

    pin_memory=True,

    persistent_workers=True,
)

# %%
model = MahjongTransformer()

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
checkpoint = torch.load(

    "../checkpoints/strategic_100k/strategic_baseline.pt",

    map_location=device,
)
# Out:
# /home/julia/miniforge3/envs/riichi-ai/lib/python3.11/site-packages/torch/cuda/__init__.py:235: UserWarning:
# NVIDIA GeForce RTX 5060 Laptop GPU with CUDA capability sm_120 is not compatible with the current PyTorch installation.
# The current PyTorch install supports CUDA capabilities sm_50 sm_60 sm_61 sm_70 sm_75 sm_80 sm_86 sm_89 sm_90 compute_90.
# If you want to use the NVIDIA GeForce RTX 5060 Laptop GPU GPU with PyTorch, please check the instructions at https://pytorch.org/get-started/locally/
#
#   warnings.warn(

# %%
model.load_state_dict(
    checkpoint["model_state_dict"]
)
# Out:
# <All keys matched successfully>

# %%
model.to(device)

model.eval()

print("Checkpoint loaded.")
# Out:
# Checkpoint loaded.

# %%
criterion = torch.nn.CrossEntropyLoss()

total_loss = 0

total_correct = 0

total_samples = 0

# %%
with torch.no_grad():

    for batch in tqdm(val_loader):

        batch = {

            k: v.to(device)
            if isinstance(v, torch.Tensor)
            else v

            for k, v in batch.items()
        }

        targets = batch["target"]

        logits_list = model(batch)

        batch_loss = 0

        for logits, target in zip(
            logits_list,
            targets,
        ):

            target = target.unsqueeze(0)

            logits = logits.unsqueeze(0)

            loss = criterion(
                logits,
                target,
            )

            batch_loss += loss.item()

            prediction = torch.argmax(
                logits,
                dim=1,
            )

            total_correct += (
                prediction == target
            ).sum().item()

            total_samples += 1

        total_loss += batch_loss
# Out:
#   0%|          | 0/1563 [00:00<?, ?it/s]/home/julia/miniforge3/envs/riichi-ai/lib/python3.11/site-packages/torch/nn/modules/transformer.py:508: UserWarning: The PyTorch API of nested tensors is in prototype stage and will change in the near future. We recommend specifying layout=torch.jagged when constructing a nested tensor, as this layout receives active development, has better operator coverage, and works with torch.compile. (Triggered internally at /home/conda/feedstock_root/build_artifacts/libtorch_1739474893324/work/aten/src/ATen/NestedTensorImpl.cpp:178.)
#   output = torch._nested_tensor_from_mask(
# 100%|██████████| 1563/1563 [02:25<00:00, 10.77it/s]

# %%
val_loss = total_loss / len(val_loader)

val_accuracy = total_correct / total_samples

print(f"Validation Loss: {val_loss:.4f}")

print(f"Validation Accuracy: {val_accuracy:.4f}")
# Out:
# Validation Loss: 64.0993
# Validation Accuracy: 0.6675

# %%
top3_correct = 0

top3_total = 0

with torch.no_grad():

    for batch in tqdm(val_loader):

        batch = {

            k: v.to(device)
            if isinstance(v, torch.Tensor)
            else v

            for k, v in batch.items()
        }

        targets = batch["target"]

        logits_list = model(batch)

        top3_correct += compute_topk_accuracy(

            logits_list,

            targets,

            k=3,
        )

        top3_total += len(targets)

top3 = top3_correct / top3_total

print(f"Top-3 Accuracy: {top3:.4f}")
# Out:
# 100%|██████████| 1563/1563 [02:35<00:00, 10.05it/s]
# Top-3 Accuracy: 0.0141

# %%
top5_correct = 0

top5_total = 0

with torch.no_grad():

    for batch in tqdm(val_loader):

        batch = {

            k: v.to(device)
            if isinstance(v, torch.Tensor)
            else v

            for k, v in batch.items()
        }

        targets = batch["target"]

        logits_list = model(batch)

        top5_correct += compute_topk_accuracy(

            logits_list,

            targets,

            k=5,
        )

        top5_total += len(targets)

top5 = top5_correct / top5_total

print(f"Top-5 Accuracy: {top5:.4f}")
# Out:
# 100%|██████████| 1563/1563 [02:30<00:00, 10.39it/s]
# Top-5 Accuracy: 0.0149

# %% [markdown]
# # Strategic Evaluation
#
# Exact action matching is insufficient for Mahjong because multiple discards can produce equivalent strategic outcomes.
#
# To address this, we evaluate:
# - Shanten preservation
# - Effective ukeire
# - Strategic mistake categories

# %%
conn = sqlite3.connect(
    "../data/discard/strategic.db"
)

# %%
results = []

# %%
NUM_SAMPLES = 10000

# %%
row_result = {}
for offset in tqdm(range(NUM_SAMPLES)):

    query = f"""
    SELECT Data
    FROM Discard
    LIMIT 1 OFFSET {offset}
    """

    row = conn.execute(
        query
    ).fetchone()

    decoded = json.loads(
        gzip.decompress(row[0])
    )

    row_result["offset"] = offset

    canonical_state = {

    "round_wind":
        decoded["round_wind"],

    "num_honba":
        decoded["num_honba"],

    "num_riichi":
        decoded["num_riichi"],

    "player_wind":
        decoded["player_wind"],

    "position":
        decoded["position"],

    "remain_tiles":
        decoded["remain_tiles"],

    "dora_indicators":
        decoded["dora_indicators"],

    "hand_tiles":
        decoded["hand_tiles"],

    "players": {

        "0": decoded["0"],
        "1": decoded["1"],
        "2": decoded["2"],
        "3": decoded["3"],
    },

    "valid_actions":
        decoded["valid_actions"],

    "action_idx":
        decoded["action_idx"],
    }

    tokens = tokenizer.tokenize(
        canonical_state
    )

    tensor_dict = tensorizer.tensorize(
        tokens
    )

    batch = collator.collate(
        [tensor_dict]
    )

    batch = {

        k: v.to(device)
        if isinstance(v, torch.Tensor)
        else v

        for k, v in batch.items()
    }

    with torch.no_grad():

        logits = model(batch)[0]

    probabilities = torch.softmax(
        logits,
        dim=0,
    )

    prediction = torch.argmax(
        probabilities
    ).item()

    expert_action = decoded[
        "valid_actions"
    ][
        decoded["action_idx"]
    ]

    model_action = decoded[
        "valid_actions"
    ][prediction]

    if expert_action["type"] != 1:
        continue

    if model_action["type"] != 1:
        continue

    expert_tile = expert_action[
        "tiles"
    ][0]

    model_tile = model_action[
        "tiles"
    ][0]

    discard_eval = evaluate_discards_ukeire(
        canonical_state
    )

    discard_lookup = {}

    for r in discard_eval:

        discard_lookup[
            r["discard"]
        ] = r

    expert_metrics = discard_lookup[
        expert_tile
    ]

    model_metrics = discard_lookup[
        model_tile
    ]

    row_result = {

    "expert_tile":
        tile136_to_string(
            expert_tile
        ),

    "model_tile":
        tile136_to_string(
            model_tile
        ),

    "same_action":
        expert_tile == model_tile,

    "expert_shanten":
        expert_metrics["shanten"],

    "model_shanten":
        model_metrics["shanten"],

    "expert_ukeire":
        expert_metrics["ukeire"],

    "model_ukeire":
        model_metrics["ukeire"],

    "shanten_difference":
        (
            expert_metrics["shanten"]
            -
            model_metrics["shanten"]
        ),

    "ukeire_difference":
        (
            expert_metrics["ukeire"]
            -
            model_metrics["ukeire"]
        ),

    "model_prob":
        probabilities[
            prediction
        ].item(),
    }

    row_result["category"] = (
        categorize_mistake(
            row_result
        )
    )

    results.append(
        row_result
    )
# Out:
# 100%|██████████| 10000/10000 [02:02<00:00, 81.67it/s]

# %%
results_df = pd.DataFrame(
    results
)

results_df.head()
# Out:
#   expert_tile model_tile  same_action  expert_shanten  model_shanten  \
# 0        east       west        False               4              4
# 1         red       west        False               4              4
# 2        west       west         True               3              3
# 3       south      south         True               3              3
# 4          2m         2m         True               3              3
#
#    expert_ukeire  model_ukeire  shanten_difference  ukeire_difference  \
# 0             66            67                   0                 -1
# 1             71            72                   0                 -1
# 2             32            32                   0                  0
# 3             52            52                   0                  0
# 4             54            54                   0                  0
#
#    model_prob         category  offset
# 0    0.534196  near_equivalent     1.0
# 1    0.534368  near_equivalent     2.0
# 2    0.460348      exact_match     3.0
# 3    0.677493      exact_match     4.0
# 4    0.652961      exact_match     5.0

# %%
results_df.groupby("category").size()
# Out:
# category
# better_shanten      315
# better_ukeire       525
# equivalent         1149
# exact_match        6716
# near_equivalent     538
# shanten_loss        330
# ukeire_loss         427
# dtype: int64

# %%
results_df.groupby("category")[

    [
        "shanten_difference",
        "ukeire_difference",
    ]

].mean()
# Out:
#                  shanten_difference  ukeire_difference
# category
# better_shanten                  1.0          24.298413
# better_ukeire                   0.0          -9.001905
# equivalent                      0.0           0.000000
# exact_match                     0.0           0.000000
# near_equivalent                 0.0          -0.198885
# shanten_loss                   -1.0         -20.539394
# ukeire_loss                     0.0           7.309133

# %%
summary = pd.DataFrame({

    "Metric": [

        "Exact Accuracy",
        "Strategic Accuracy",
        "Mean Ukeire Difference",
    ],

    "Value": [

        results_df["same_action"].mean(),

        results_df["category"].isin([
            "exact_match",
            "equivalent",
            "near_equivalent",
        ]).mean(),

        results_df["ukeire_difference"].mean(),
    ]
})

summary
# Out:
#                    Metric   Value
# 0          Exact Accuracy  0.6716
# 1      Strategic Accuracy  0.8403
# 2  Mean Ukeire Difference -0.0836

# %%
distribution = (

    results_df["category"]

    .value_counts(normalize=True)
)

distribution
# Out:
# category
# exact_match        0.6716
# equivalent         0.1149
# near_equivalent    0.0538
# better_ukeire      0.0525
# ukeire_loss        0.0427
# shanten_loss       0.0330
# better_shanten     0.0315
# Name: proportion, dtype: float64

# %%
results_df[
    "ukeire_difference"
].mean()
# Out:
# np.float64(-0.0836)

# %%
results_df[
    "same_action"
].mean()
# Out:
# np.float64(0.6716)

# %%
worst = results_df[

    results_df["category"].isin([
        "catastrophic",
        "shanten_loss",
        "ukeire_loss",
    ])
]

worst = worst.sort_values(

    by=[
        "category",
        "ukeire_difference",
    ],

    ascending=[
        True,
        False,
    ],
)

worst.head(20)
# Out:
#      expert_tile model_tile  same_action  expert_shanten  model_shanten  \
# 54            8m        red        False               0              1
# 868           6m         6p        False               0              1
# 1837          9s         1s        False               1              2
# 1839       south      white        False               1              2
# 9125          6p         8p        False               1              2
# 9412        east        red        False               1              2
# 9413          3p         9s        False               1              2
# 9414          3p         9s        False               1              2
# 255           6m         6s        False               0              1
# 3091          3p         4s        False               0              1
# 5393          3s         6p        False               0              1
# 5485          8s         3s        False               1              2
# 9404          5p         1s        False               2              3
# 9620          8p         4s        False               0              1
# 919           2p         7p        False               1              2
# 6452          5m         4m        False               0              1
# 8611          9p         7p        False               1              2
# 9335          8m         1s        False               1              2
# 9416       north      south        False               0              1
# 9488          8m         2s        False               0              1
#
#       expert_ukeire  model_ukeire  shanten_difference  ukeire_difference  \
# 54                3             3                  -1                  0
# 868               3             3                  -1                  0
# 1837              6             6                  -1                  0
# 1839              5             5                  -1                  0
# 9125              5             5                  -1                  0
# 9412              5             5                  -1                  0
# 9413              5             5                  -1                  0
# 9414              5             5                  -1                  0
# 255               6             7                  -1                 -1
# 3091              4             5                  -1                 -1
# 5393              8             9                  -1                 -1
# 5485             12            13                  -1                 -1
# 9404             11            12                  -1                 -1
# 9620              2             3                  -1                 -1
# 919               6             8                  -1                 -2
# 6452              8            10                  -1                 -2
# 8611              7             9                  -1                 -2
# 9335             16            18                  -1                 -2
# 9416              3             5                  -1                 -2
# 9488              5             7                  -1                 -2
#
#       model_prob      category  offset
# 54      0.315576  shanten_loss    55.0
# 868     0.388298  shanten_loss   869.0
# 1837    0.705205  shanten_loss  1838.0
# 1839    0.271688  shanten_loss  1840.0
# 9125    0.313351  shanten_loss  9126.0
# 9412    0.235119  shanten_loss  9413.0
# 9413    0.310754  shanten_loss  9414.0
# 9414    0.343189  shanten_loss  9415.0
# 255     0.428052  shanten_loss   256.0
# 3091    0.324530  shanten_loss  3092.0
# 5393    0.267685  shanten_loss  5394.0
# 5485    0.182165  shanten_loss  5486.0
# 9404    0.398767  shanten_loss  9405.0
# 9620    0.197672  shanten_loss  9621.0
# 919     0.203412  shanten_loss   920.0
# 6452    0.295878  shanten_loss  6453.0
# 8611    0.399360  shanten_loss  8612.0
# 9335    0.405539  shanten_loss  9336.0
# 9416    0.206564  shanten_loss  9417.0
# 9488    0.196901  shanten_loss  9489.0

# %%
best = results_df[

    results_df["category"].isin([
        "better_shanten",
        "better_ukeire",
        "near_equivalent",
        "equivalent",
    ])
]

best = best.sort_values(

    by=[
        "category",
        "ukeire_difference",
    ],

    ascending=[
        True,
        True,
    ],
)

best.head(20)
# Out:
#      expert_tile model_tile  same_action  expert_shanten  model_shanten  \
# 227           6p         1s        False               2              1
# 1653          1s         7s        False               2              1
# 1744          1s         7m        False               1              0
# 2120          7s         5m        False               2              1
# 1263          6m      north        False               3              2
# 1841          9s         5p        False               3              2
# 2190          8s       west        False               3              2
# 2635          9s         6m        False               3              2
# 4197          7s       west        False               3              2
# 4975          4s         1m        False               2              1
# 1274          1p      white        False               3              2
# 2483          9p         7m        False               2              1
# 3411       north         6p        False               2              1
# 4411          4p         1m        False               2              1
# 4973          1m         7m        False               2              1
# 5026          3p         9s        False               2              1
# 9266          2s      green        False               4              3
# 2211          3p         9m        False               2              1
# 3783          5p         9p        False               1              0
# 5522        east      green        False               1              0
#
#       expert_ukeire  model_ukeire  shanten_difference  ukeire_difference  \
# 227              12            12                   1                  0
# 1653              8             8                   1                  0
# 1744              3             3                   1                  0
# 2120              8             8                   1                  0
# 1263             46            45                   1                  1
# 1841              7             6                   1                  1
# 2190             14            13                   1                  1
# 2635             13            12                   1                  1
# 4197             43            42                   1                  1
# 4975              8             7                   1                  1
# 1274             14            12                   1                  2
# 2483             12            10                   1                  2
# 3411             10             8                   1                  2
# 4411             15            13                   1                  2
# 4973             10             8                   1                  2
# 5026             16            14                   1                  2
# 9266             41            39                   1                  2
# 2211             16            13                   1                  3
# 3783              7             4                   1                  3
# 5522              9             6                   1                  3
#
#       model_prob        category  offset
# 227     0.769425  better_shanten   228.0
# 1653    0.509511  better_shanten  1654.0
# 1744    0.420304  better_shanten  1745.0
# 2120    0.320436  better_shanten  2121.0
# 1263    0.540879  better_shanten  1264.0
# 1841    0.360992  better_shanten  1842.0
# 2190    0.580577  better_shanten  2191.0
# 2635    0.792623  better_shanten  2636.0
# 4197    0.591456  better_shanten  4198.0
# 4975    0.633252  better_shanten  4976.0
# 1274    0.450144  better_shanten  1275.0
# 2483    0.711633  better_shanten  2484.0
# 3411    0.779481  better_shanten  3412.0
# 4411    0.702117  better_shanten  4412.0
# 4973    0.400190  better_shanten  4974.0
# 5026    0.738050  better_shanten  5027.0
# 9266    0.425691  better_shanten  9267.0
# 2211    0.433451  better_shanten  2212.0
# 3783    0.923178  better_shanten  3784.0
# 5522    0.710721  better_shanten  5523.0

# %%
model_better = results_df[
    results_df["category"].isin([
        "better_shanten",
        "better_ukeire",
    ])
]

model_better.head(20)
# Out:
#     expert_tile model_tile  same_action  expert_shanten  model_shanten  \
# 39           1p         8s        False               2              1
# 80           7m         1s        False               3              3
# 95        green         2p        False               3              2
# 99           5s      north        False               3              3
# 105          9m      north        False               3              3
# 161          3m         1m        False               1              1
# 180          6s         3m        False               2              2
# 184          9s         9m        False               1              1
# 192          9m      south        False               2              2
# 193          1s        red        False               3              3
# 227          6p         1s        False               2              1
# 228          7s         7m        False               3              2
# 232          4s         2m        False               3              2
# 247          1s         3m        False               2              2
# 248          8s         2m        False               1              1
# 264          9s       west        False               3              3
# 280          7m        red        False               3              2
# 281          3s         9m        False               4              3
# 283          2m        red        False               3              3
# 284          2m        red        False               4              3
#
#      expert_ukeire  model_ukeire  shanten_difference  ukeire_difference  \
# 39              35            12                   1                 23
# 80              23            42                   0                -19
# 95              60            25                   1                 35
# 99              53            69                   0                -16
# 105             64            72                   0                 -8
# 161             17            24                   0                 -7
# 180             18            21                   0                 -3
# 184              6            10                   0                 -4
# 192             38            47                   0                 -9
# 193             54            62                   0                 -8
# 227             12            12                   1                  0
# 228             57            18                   1                 39
# 232             46            17                   1                 29
# 247             21            25                   0                 -4
# 248              7            14                   0                 -7
# 264             23            31                   0                 -8
# 280             28            15                   1                 13
# 281             50            43                   1                  7
# 283             11            14                   0                 -3
# 284             45            10                   1                 35
#
#      model_prob        category  offset
# 39     0.615280  better_shanten    40.0
# 80     0.922128   better_ukeire    81.0
# 95     0.547336  better_shanten    96.0
# 99     0.631739   better_ukeire   100.0
# 105    0.776517   better_ukeire   106.0
# 161    0.466593   better_ukeire   162.0
# 180    0.206107   better_ukeire   181.0
# 184    0.488732   better_ukeire   185.0
# 192    0.627803   better_ukeire   193.0
# 193    0.524794   better_ukeire   194.0
# 227    0.769425  better_shanten   228.0
# 228    0.630961  better_shanten   229.0
# 232    0.766803  better_shanten   233.0
# 247    0.304678   better_ukeire   248.0
# 248    0.671067   better_ukeire   249.0
# 264    0.423894   better_ukeire   265.0
# 280    0.413132  better_shanten   281.0
# 281    0.386359  better_shanten   282.0
# 283    0.188723   better_ukeire   284.0
# 284    0.423614  better_shanten   285.0

# %%
high_confidence_mistakes = results_df[

    results_df["same_action"] == False
]

high_confidence_mistakes = high_confidence_mistakes.sort_values(

    by="model_prob",

    ascending=False,
)

high_confidence_mistakes.head(20)
# Out:
#      expert_tile model_tile  same_action  expert_shanten  model_shanten  \
# 5942          2m         2s        False               1              1
# 4788          6s         1p        False               1              1
# 2609          3m         4s        False               1              1
# 6328          3p         9m        False               1              1
# 3622          7p         2s        False               1              1
# 9016          9s         6m        False               2              1
# 4406          1s         3p        False               1              0
# 8500          6s      white        False               2              2
# 5058          7s      south        False               2              2
# 8393          4m       west        False               3              3
# 567           5s         9m        False               1              1
# 5643          3m      south        False               3              3
# 4387          1s      north        False               3              2
# 7217          7p         1p        False               1              1
# 7418         red         4p        False               1              1
# 3168          7s       east        False               1              1
# 6947          5s         9m        False               0              0
# 3616          2m      green        False               2              2
# 2186          8s         1s        False               3              2
# 3956          7p         2s        False               1              1
#
#       expert_ukeire  model_ukeire  shanten_difference  ukeire_difference  \
# 5942             12            12                   0                  0
# 4788             11            15                   0                 -4
# 2609             11            14                   0                 -3
# 6328             10            10                   0                  0
# 3622             12            15                   0                 -3
# 9016             24            10                   1                 14
# 4406             11             7                   1                  4
# 8500             23            23                   0                  0
# 5058             32            48                   0                -16
# 8393             35            36                   0                 -1
# 567               5             5                   0                  0
# 5643             35            35                   0                  0
# 4387             76            11                   1                 65
# 7217             15            15                   0                  0
# 7418             29            20                   0                  9
# 3168             15            15                   0                  0
# 6947              2             4                   0                 -2
# 3616             21            21                   0                  0
# 2186             55            43                   1                 12
# 3956             10            10                   0                  0
#
#       model_prob         category  offset
# 5942    0.988758       equivalent  5943.0
# 4788    0.987525    better_ukeire  4789.0
# 2609    0.986322    better_ukeire  2610.0
# 6328    0.984128       equivalent  6329.0
# 3622    0.981637    better_ukeire  3623.0
# 9016    0.980945   better_shanten  9017.0
# 4406    0.979324   better_shanten  4407.0
# 8500    0.978532       equivalent  8501.0
# 5058    0.978013    better_ukeire  5059.0
# 8393    0.977162  near_equivalent  8394.0
# 567     0.975558       equivalent   568.0
# 5643    0.974170       equivalent  5644.0
# 4387    0.972762   better_shanten  4388.0
# 7217    0.972049       equivalent  7218.0
# 7418    0.970448      ukeire_loss  7419.0
# 3168    0.969671       equivalent  3169.0
# 6947    0.969666  near_equivalent  6948.0
# 3616    0.967955       equivalent  3617.0
# 2186    0.963822   better_shanten  2187.0
# 3956    0.963360       equivalent  3957.0

# %%
results_df["category"].value_counts()
# Out:
# category
# exact_match        6716
# equivalent         1149
# near_equivalent     538
# better_ukeire       525
# ukeire_loss         427
# shanten_loss        330
# better_shanten      315
# Name: count, dtype: int64

# %%
results_df.to_csv(

    "../reports/strategic_validation_analysis_100k.csv",

    index=False,
)

print("Saved.")
# Out:
# Saved.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_theme(style="whitegrid")

# %%
plt.figure(figsize=(12, 6))

sns.barplot(

    x=distribution.index,

    y=distribution.values,
)

plt.ylabel("Proportion")

plt.xlabel("Category")

plt.title(
    "Strategic Classification of Model Decisions"
)

plt.xticks(rotation=20)

plt.ylim(0, 1)

for i, value in enumerate(
    distribution.values
):

    plt.text(

        i,

        value + 0.01,

        f"{value:.1%}",

        ha="center",
    )

plt.tight_layout()

plt.show()

# %%
plt.savefig(

    "../reports/figures/category_distribution_100k.png",

    dpi=300,

    bbox_inches="tight",
)

# %%
exact_accuracy = (
    results_df["same_action"]
    .mean()
)

strategic_accuracy = (

    results_df["category"]

    .isin([
        "exact_match",
        "equivalent",
        "near_equivalent",
        "better_ukeire",
        "better_shanten",
    ])

    .mean()
)

comparison_df = pd.DataFrame({

    "Metric": [

        "Exact Accuracy",

        "Strategic Accuracy",
    ],

    "Value": [

        exact_accuracy,

        strategic_accuracy,
    ]
})

# %%
plt.figure(figsize=(8, 6))

sns.barplot(

    data=comparison_df,

    x="Metric",

    y="Value",
)

plt.ylim(0, 1)

plt.ylabel("Accuracy")

plt.title(
    "Exact vs Strategic Accuracy"
)

for i, value in enumerate(
    comparison_df["Value"]
):

    plt.text(

        i,

        value + 0.01,

        f"{value:.1%}",

        ha="center",
    )

plt.show()

# %%
plt.savefig(

    "../reports/figures/accuracy_difference_100k.png",

    dpi=300,

    bbox_inches="tight",
)

# %%
plt.figure(figsize=(10, 6))

sns.histplot(

    results_df["ukeire_difference"],

    bins=20,
)

plt.xlabel(
    "Expert Ukeire - Model Ukeire"
)

plt.ylabel("Frequency")

plt.title(
    "Ukeire Difference Distribution"
)

plt.show()

# %%
plt.savefig(

    "../reports/figures/ukeire_distribution_100k.png",

    dpi=300,

    bbox_inches="tight",
)

# %%
plt.figure(figsize=(12, 6))

sns.boxplot(

    data=results_df,

    x="category",

    y="model_prob",
)

plt.xticks(rotation=20)

plt.xlabel("Category")

plt.ylabel("Prediction Confidence")

plt.title(
    "Confidence Distribution by Category"
)

plt.show()

# %%
plt.savefig(

    "../reports/figures/category_confidence_distribution_100k.png",

    dpi=300,

    bbox_inches="tight",
)

# %%
plt.figure(figsize=(10, 6))

sns.histplot(

    results_df["model_prob"],

    bins=20,
)

plt.xlabel(
    "Model Confidence"
)

plt.ylabel("Frequency")

plt.title(
    "Model Confidence Distribution"
)

plt.show()

# %%
plt.savefig(

    "../reports/figures/confidence_distribution_100k.png",

    dpi=300,

    bbox_inches="tight",
)

# %%
results_df.to_csv(

    "../reports/tables/100k_results.csv",

    index=False,
)

# %%
distribution.to_csv(

    "../reports/tables/100k_distribution.csv"
)

# %%
summary = pd.DataFrame({

    "metric": [

        "exact_accuracy",

        "strategic_accuracy",

        "mean_confidence",

        "mean_ukeire_difference",
    ],

    "value": [

        results_df["same_action"].mean(),

        results_df["category"].isin([

            "exact_match",

            "equivalent",

            "near_equivalent",

            "better_ukeire",

            "better_shanten",

        ]).mean(),

        results_df["model_prob"].mean(),

        results_df["ukeire_difference"].mean(),
    ]
})

# %%
summary.to_csv(

    "../reports/tables/100k_summary.csv",

    index=False,
)

# %% [markdown]
# # Case Studies
#
# Aggregate metrics provide a high-level overview of model performance, but they do not explain the nature of individual decisions.
#
# This section presents representative examples from each strategic category:
#
# - Exact Match
# - Near Equivalent
# - Better Ukeire
# - Shanten Loss
#
# For each example we inspect:
#
# - The full Mahjong state
# - The expert discard
# - The model discard
# - Shanten values
# - Effective ukeire values
#
# This allows qualitative analysis of the model's strategic behavior.

# %%
def load_state(offset):

    query = f"""
    SELECT Data
    FROM Discard
    LIMIT 1 OFFSET {offset}
    """

    row = conn.execute(
        query
    ).fetchone()

    decoded = json.loads(
        gzip.decompress(
            row[0]
        )
    )

    canonical_state = {

        "round_wind":
            decoded["round_wind"],

        "num_honba":
            decoded["num_honba"],

        "num_riichi":
            decoded["num_riichi"],

        "player_wind":
            decoded["player_wind"],

        "position":
            decoded["position"],

        "remain_tiles":
            decoded["remain_tiles"],

        "dora_indicators":
            decoded["dora_indicators"],

        "hand_tiles":
            decoded["hand_tiles"],

        "players": {

            "0": decoded["0"],
            "1": decoded["1"],
            "2": decoded["2"],
            "3": decoded["3"],
        },

        "valid_actions":
            decoded["valid_actions"],

        "action_idx":
            decoded["action_idx"],
    }

    return canonical_state

# %%
from src.utils.state_renderer import (
    render_state
)

# %% [markdown]
# ## Case Study 1 — Exact Match
#
# This example shows a state where the transformer selects the same discard as the expert player.

# %%
exact_case = results_df[

    results_df["category"]
    ==
    "exact_match"

].sample(1)

exact_case
# Out:
#      expert_tile model_tile  same_action  expert_shanten  model_shanten  \
# 9579        west       west         True               5              5
#
#       expert_ukeire  model_ukeire  shanten_difference  ukeire_difference  \
# 9579             88            88                   0                  0
#
#       model_prob     category  offset
# 9579    0.634494  exact_match  9580.0

# %%
state = load_state(

    int(
        exact_case.iloc[0]["offset"]
    ) - 1
)

render_state(state)
# Out:
# ==================================================
# ROUND
# ==================================================
#
# Round Wind: 0
# Honba: 2
# Riichi Sticks: 1
# Remaining Tiles: 68
#
# Dora Indicators: green
#
# ==================================================
# PLAYER 0
# ==================================================
#
# Points: 25100
# Riichi: False
# MELDS:
# None
#
# DISCARDS:
# 1s
#
# ==================================================
# PLAYER 1
# ==================================================
#
# Points: 21000
# Riichi: False
#
# HAND:
# 5m 9m 1p 3p 9p 2s 5s 6s 6s 8s west white red 4p
#
# MELDS:
# None
#
# DISCARDS:
#
#
# ==================================================
# PLAYER 2
# ==================================================
#
# Points: 26100
# Riichi: False
# MELDS:
# None
#
# DISCARDS:
#
#
# ==================================================
# PLAYER 3
# ==================================================
#
# Points: 26800
# Riichi: False
# MELDS:
# None
#
# DISCARDS:

# %%
exact_case.T
# Out:
#                            9579
# expert_tile                west
# model_tile                 west
# same_action                True
# expert_shanten                5
# model_shanten                 5
# expert_ukeire                88
# model_ukeire                 88
# shanten_difference            0
# ukeire_difference             0
# model_prob             0.634494
# category            exact_match
# offset                   9580.0

# %% [markdown]
# ### Discussion
#
# The model reproduces the expert action exactly.
#
# This suggests that the learned policy captures the same local strategic considerations as the expert in this situation.

# %% [markdown]
# ## Case Study 2 — Near Equivalent
#
# This example shows a disagreement between the model and the expert.
#
# However, the resulting hand quality remains strategically similar.

# %%
near_case = results_df[

    results_df["category"]
    ==
    "near_equivalent"

].sample(1)

near_case
# Out:
#      expert_tile model_tile  same_action  expert_shanten  model_shanten  \
# 1064          3m         4s        False               0              0
#
#       expert_ukeire  model_ukeire  shanten_difference  ukeire_difference  \
# 1064              3             4                   0                 -1
#
#       model_prob         category  offset
# 1064     0.30655  near_equivalent  1065.0

# %%
state = load_state(

    int(
        near_case.iloc[0]["offset"]
    ) - 1
)

render_state(state)
# Out:
# ==================================================
# ROUND
# ==================================================
#
# Round Wind: 1
# Honba: 1
# Riichi Sticks: 0
# Remaining Tiles: 33
#
# Dora Indicators: 9m
#
# ==================================================
# PLAYER 0
# ==================================================
#
# Points: 32600
# Riichi: False
# MELDS:
# None
#
# DISCARDS:
# west 9s green* 8s 3s* 4p 3s* 6s 5s 3p 3p 3s
#
# ==================================================
# PLAYER 1
# ==================================================
#
# Points: 25700
# Riichi: False
# MELDS:
# None
#
# DISCARDS:
# west south 9s north 4p north* 4p 7m 7s 9m
#
# ==================================================
# PLAYER 2
# ==================================================
#
# Points: 26000
# Riichi: False
#
# HAND:
# 1m 3m 7p 8p 4s 4s 4s 6p
#
# MELDS:
# pon: ['south', 'south', 'south']
# chi: ['7s', '8s', '9s']
#
# DISCARDS:
# 9m north* 9m* 1s* 8m* 5m 9s* green*
#
# ==================================================
# PLAYER 3
# ==================================================
#
# Points: 15700
# Riichi: False
# MELDS:
# pon: ['west', 'west', 'west']
# pon: ['green', 'green', 'green']
# pon: ['3p', '3p', '3p']
#
# DISCARDS:
# 9p 3m* 5s* 3s* 4p* south* 6s* 7m 9s* 7s* 7m*

# %%
near_case.T
# Out:
#                                1064
# expert_tile                      3m
# model_tile                       4s
# same_action                   False
# expert_shanten                    0
# model_shanten                     0
# expert_ukeire                     3
# model_ukeire                      4
# shanten_difference                0
# ukeire_difference                -1
# model_prob                  0.30655
# category            near_equivalent
# offset                       1065.0

# %% [markdown]
# ### Discussion
#
# The transformer chooses a different discard from the expert.
#
# Despite this disagreement, both actions preserve hand efficiency and result in similar strategic outcomes.

# %% [markdown]
# ## Case Study 3 — Better Ukeire
#
# This example shows a situation where the model chooses a discard that results in a larger effective ukeire than the expert action.

# %%
better_case = results_df[

    results_df["category"]
    ==
    "better_ukeire"

].sort_values(

    by="ukeire_difference",

    ascending=True,
)

better_case.head(1)
# Out:
#      expert_tile model_tile  same_action  expert_shanten  model_shanten  \
# 8208          9p      green        False               5              5
#
#       expert_ukeire  model_ukeire  shanten_difference  ukeire_difference  \
# 8208             30            80                   0                -50
#
#       model_prob       category  offset
# 8208    0.413152  better_ukeire  8209.0

# %%
state = load_state(

    int(
        better_case.iloc[0]["offset"]
    ) - 1
)

render_state(state)
# Out:
# ==================================================
# ROUND
# ==================================================
#
# Round Wind: 0
# Honba: 0
# Riichi Sticks: 0
# Remaining Tiles: 58
#
# Dora Indicators: 9p
#
# ==================================================
# PLAYER 0
# ==================================================
#
# Points: 24700
# Riichi: False
# MELDS:
# None
#
# DISCARDS:
# south west 9m
#
# ==================================================
# PLAYER 1
# ==================================================
#
# Points: 26100
# Riichi: False
# MELDS:
# None
#
# DISCARDS:
# 9s 2m* north
#
# ==================================================
# PLAYER 2
# ==================================================
#
# Points: 24700
# Riichi: False
# MELDS:
# None
#
# DISCARDS:
# north green 4s
#
# ==================================================
# PLAYER 3
# ==================================================
#
# Points: 24500
# Riichi: False
#
# HAND:
# 2m 5m 8m 9m 1p 8p 8p 9p 5s 8s white green red 6p
#
# MELDS:
# None
#
# DISCARDS:
# south west

# %%
better_case.head(1).T
# Out:
#                              8208
# expert_tile                    9p
# model_tile                  green
# same_action                 False
# expert_shanten                  5
# model_shanten                   5
# expert_ukeire                  30
# model_ukeire                   80
# shanten_difference              0
# ukeire_difference             -50
# model_prob               0.413152
# category            better_ukeire
# offset                     8209.0

# %% [markdown]
# ### Discussion
#
# The model selects a discard that increases effective ukeire while preserving shanten.
#
# This does not necessarily imply that the model found a superior Mahjong decision, since defensive considerations, hand value, and game context are not captured by the evaluation metrics.
#
# However, it demonstrates that expert imitation and efficiency optimization are not always identical.

# %% [markdown]
# ## Case Study 4 — Shanten Loss
#
# This example illustrates a genuine strategic mistake.
#
# The model chooses a discard that worsens the hand's shanten number compared to the expert action.

# %%
bad_case = results_df[

    results_df["category"]
    ==
    "shanten_loss"

].head(1)

bad_case
# Out:
#    expert_tile model_tile  same_action  expert_shanten  model_shanten  \
# 44          5s         7p        False               0              1
#
#     expert_ukeire  model_ukeire  shanten_difference  ukeire_difference  \
# 44              3            20                  -1                -17
#
#     model_prob      category  offset
# 44    0.322717  shanten_loss    45.0

# %%
state = load_state(

    int(
        bad_case.iloc[0]["offset"]
    ) - 1
)

render_state(state)
# Out:
# ==================================================
# ROUND
# ==================================================
#
# Round Wind: 0
# Honba: 0
# Riichi Sticks: 0
# Remaining Tiles: 3
#
# Dora Indicators: west green
#
# ==================================================
# PLAYER 0
# ==================================================
#
# Points: 22500
# Riichi: True
# MELDS:
# ankan: ['3s', '3s', '3s', '3s']
#
# DISCARDS:
# 1p 1s red 8s 8p 5p 9s* 5s* 2p* 1s* 2p* 8m* 2s* 5m* 7s* green* 7p*
#
# ==================================================
# PLAYER 1
# ==================================================
#
# Points: 32700
# Riichi: False
# MELDS:
# None
#
# DISCARDS:
# east red east* 8s 9s* 8s* north* south* 1p 4s 8p north* 8m 2s 2s 2s* 8p*
#
# ==================================================
# PLAYER 2
# ==================================================
#
# Points: 19800
# Riichi: False
#
# HAND:
# 1m 1m 3m 4m 5m 5p 7p 4s 5s 6s 5s
#
# MELDS:
# chi: ['6m', '7m', '8m']
#
# DISCARDS:
# 1s 9m west* 7p 4s 7m* 4p 1s south* 9p* 9s 1p 1p 8s 5p south*
#
# ==================================================
# PLAYER 3
# ==================================================
#
# Points: 25000
# Riichi: False
# MELDS:
# None
#
# DISCARDS:
# south west 9p east white red north 9s* 6p green* 2p 8m 2p east* 7s 7s

# %%
bad_case.T
# Out:
#                               44
# expert_tile                   5s
# model_tile                    7p
# same_action                False
# expert_shanten                 0
# model_shanten                  1
# expert_ukeire                  3
# model_ukeire                  20
# shanten_difference            -1
# ukeire_difference            -17
# model_prob              0.322717
# category            shanten_loss
# offset                      45.0

# %% [markdown]
# ### Discussion
#
# Unlike previous examples, the model's action directly worsens hand progression.
#
# These cases represent true strategic failures and provide insight into the remaining weaknesses of the learned policy.

# %% [markdown]
# # Case Study Summary
#
# The qualitative examples support the quantitative findings presented earlier.
#
# Several disagreements between the model and expert players correspond to strategically equivalent alternatives rather than genuine mistakes.
#
# Furthermore, some model decisions produce higher effective ukeire than the expert action, suggesting that exact imitation accuracy alone is insufficient to characterize Mahjong policy quality.
#
# The most informative failures are the shanten loss cases, which represent situations where the model genuinely degrades hand efficiency.
